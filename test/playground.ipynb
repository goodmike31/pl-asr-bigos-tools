# %%
#apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install Cython
# !pip install nemo_toolkit['all']
# Out:
# Requirement already satisfied: Cython in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (3.0.8)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: nemo_toolkit[all] in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (1.22.0)
# Requirement already satisfied: ruamel.yaml in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.18.6)
# Requirement already satisfied: scikit-learn in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.23.5)
# Requirement already satisfied: triton in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: python-dateutil in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: tensorboard in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.15.2)
# Requirement already satisfied: tqdm>=4.41.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (4.66.1)
# Requirement already satisfied: setuptools>=65.5.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (69.0.3)
# Requirement already satisfied: onnx>=1.7.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: numba in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.59.0)
# Requirement already satisfied: wrapt in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.16.0)
# Requirement already satisfied: huggingface-hub in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.20.3)
# Requirement already satisfied: text-unidecode in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: wget in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: torch in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: packaging in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (23.2)
# Requirement already satisfied: matplotlib in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.8.2)
# Requirement already satisfied: datasets in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.17.0)
# Requirement already satisfied: braceexpand in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.7)
# Requirement already satisfied: boto3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.34.39)
# Requirement already satisfied: jieba in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.42.1)
# Requirement already satisfied: gdown in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (5.1.0)
# Requirement already satisfied: editdistance in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pypinyin-dict in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: pyannote.core in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: parameterized in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: zarr in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.16.1)
# Requirement already satisfied: nltk>=3.6.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: ipywidgets in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (8.1.2)
# Requirement already satisfied: kaldi-python-io in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: tensorstore<0.1.46 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.45)
# Requirement already satisfied: pandas in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: pydantic<2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.10.14)
# Requirement already satisfied: rapidfuzz in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.13.7)
# Requirement already satisfied: pypinyin in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.50.0)
# Requirement already satisfied: pyannote.metrics in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.2.1)
# Requirement already satisfied: librosa>=0.10.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.10.1)
# Requirement already satisfied: progress>=1.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.6)
# Requirement already satisfied: ijson in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.2.3)
# Requirement already satisfied: wandb in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.16.3)
# Requirement already satisfied: jiwer>=2.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.5.2)
# Requirement already satisfied: torchmetrics>=0.11.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.3.0.post0)
# Requirement already satisfied: sacremoses>=0.0.43 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.1)
# Requirement already satisfied: black==19.10b0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (19.10b0)
# Requirement already satisfied: einops in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: youtokentome>=1.0.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: h5py in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.10.0)
# Requirement already satisfied: sphinx in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (7.2.6)
# Requirement already satisfied: soundfile in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: megatron-core==0.4.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: tabulate>=0.8.7 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: fasttext in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.9.2)
# Requirement already satisfied: scipy>=0.14 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.12.0)
# Requirement already satisfied: marshmallow in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (3.20.2)
# Requirement already satisfied: markdown2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.4.12)
# Requirement already satisfied: omegaconf<=2.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.3.0)
# Requirement already satisfied: pytest in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (8.0.0)
# Requirement already satisfied: pytest-runner in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (6.0.1)
# Requirement already satisfied: ftfy in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (6.1.3)
# Requirement already satisfied: textdistance>=4.1.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (4.6.1)
# Requirement already satisfied: kornia in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: texterrors in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.4.4)
# Requirement already satisfied: isort<6.0.0,>5.1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (5.13.2)
# Requirement already satisfied: sox in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: nemo-text-processing in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.2.2rc0)
# Requirement already satisfied: faiss-cpu in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.7.4)
# Requirement already satisfied: hydra-core<=1.3.2,>1.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.3.2)
# Requirement already satisfied: pytorch-lightning<=2.0.7,>=2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.0.7)
# Requirement already satisfied: flask-restful in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.3.10)
# Requirement already satisfied: rouge-score in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: transformers>=4.36.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (4.37.2)
# Requirement already satisfied: g2p-en in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: lightning-utilities<0.10.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: kaldiio in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.18.0)
# Requirement already satisfied: click==8.0.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (8.0.2)
# Requirement already satisfied: resampy in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: inflect in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (7.0.0)
# Requirement already satisfied: pangu in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (4.0.6.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.99)
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.1.62)
# Requirement already satisfied: sacrebleu in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: attrdict in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: opencc<1.1.7 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (1.1.6)
# Requirement already satisfied: sphinxcontrib-bibtex in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.6.2)
# Requirement already satisfied: sentence-transformers in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (2.3.1)
# Requirement already satisfied: pydub in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo_toolkit[all]) (0.25.1)
# Requirement already satisfied: pathspec<1,>=0.6 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: regex in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (2023.12.25)
# Requirement already satisfied: toml>=0.9.4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: typed-ast>=1.4.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (1.5.5)
# Requirement already satisfied: appdirs in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: attrs>=18.1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from black==19.10b0->nemo_toolkit[all]) (23.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from hydra-core<=1.3.2,>1.3->nemo_toolkit[all]) (4.9.3)
# Requirement already satisfied: pooch>=1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (4.9.0)
# Requirement already satisfied: msgpack>=1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (1.0.7)
# Requirement already satisfied: lazy-loader>=0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (0.3)
# Requirement already satisfied: soxr>=0.3.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (0.3.7)
# Requirement already satisfied: joblib>=0.14 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[all]) (3.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: pillow>=8 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (4.48.1)
# Requirement already satisfied: cycler>=0.10 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from numba->nemo_toolkit[all]) (0.42.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from omegaconf<=2.3->nemo_toolkit[all]) (6.0.1)
# Requirement already satisfied: protobuf>=3.20.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.25.2)
# Requirement already satisfied: six>=1.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from python-dateutil->nemo_toolkit[all]) (1.16.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[all]) (2023.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from scikit-learn->nemo_toolkit[all]) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from soundfile->nemo_toolkit[all]) (1.16.0)
# Requirement already satisfied: jinja2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (3.1.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.0.106)
# Requirement already satisfied: filelock in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (3.13.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (10.3.2.106)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.3.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (2.19.3)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (12.1.105)
# Requirement already satisfied: sympy in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (1.12)
# Requirement already satisfied: networkx in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from torch->nemo_toolkit[all]) (3.2.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->nemo_toolkit[all]) (12.3.101)
# Requirement already satisfied: requests in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[all]) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[all]) (0.15.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.39 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from boto3->nemo_toolkit[all]) (1.34.39)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from boto3->nemo_toolkit[all]) (0.10.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from boto3->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: multiprocess in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (0.70.16)
# Requirement already satisfied: aiohttp in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (3.9.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (15.0.0)
# Requirement already satisfied: xxhash in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: pyarrow-hotfix in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from datasets->nemo_toolkit[all]) (0.3.8)
# Requirement already satisfied: pybind11>=2.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from fasttext->nemo_toolkit[all]) (2.11.1)
# Requirement already satisfied: pytz in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from flask-restful->nemo_toolkit[all]) (2023.3.post1)
# Requirement already satisfied: Flask>=0.8 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from flask-restful->nemo_toolkit[all]) (2.2.5)
# Requirement already satisfied: aniso8601>=0.82 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from flask-restful->nemo_toolkit[all]) (9.0.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ftfy->nemo_toolkit[all]) (0.2.13)
# Requirement already satisfied: distance>=0.1.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from g2p-en->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: beautifulsoup4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from gdown->nemo_toolkit[all]) (4.12.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[all]) (3.0.10)
# Requirement already satisfied: ipython>=6.1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[all]) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[all]) (5.14.1)
# Requirement already satisfied: comm>=0.1.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[all]) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[all]) (4.0.10)
# Requirement already satisfied: cdifflib in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo-text-processing->nemo_toolkit[all]) (1.2.6)
# Requirement already satisfied: pynini==2.1.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from nemo-text-processing->nemo_toolkit[all]) (2.1.5)
# Requirement already satisfied: Cython>=0.29 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pynini==2.1.5->nemo-text-processing->nemo_toolkit[all]) (3.0.8)
# Requirement already satisfied: tzdata>=2022.7 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pandas->nemo_toolkit[all]) (2023.4)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pyannote.metrics->nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: pyannote.database>=4.0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pyannote.metrics->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pytest->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pytest->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: iniconfig in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pytest->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.3.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pytest->nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: absl-py in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from rouge-score->nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: lxml in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sacrebleu->nemo_toolkit[all]) (5.1.0)
# Requirement already satisfied: colorama in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sacrebleu->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: portalocker in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sacrebleu->nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: babel>=2.9 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (2.14.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (2.0.5)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.0.8)
# Requirement already satisfied: snowballstemmer>=2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: docutils<0.21,>=0.18.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (0.20.1)
# Requirement already satisfied: imagesize>=1.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.1.10)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (0.7.16)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: Pygments>=2.14 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (2.17.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinx->nemo_toolkit[all]) (1.0.7)
# Requirement already satisfied: pybtex>=0.24 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (3.0.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (2.27.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (1.60.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[all]) (3.5.2)
# Requirement already satisfied: termcolor in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from texterrors->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: plac in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from texterrors->nemo_toolkit[all]) (1.4.2)
# Requirement already satisfied: loguru in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from texterrors->nemo_toolkit[all]) (0.7.2)
# Requirement already satisfied: Levenshtein in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from texterrors->nemo_toolkit[all]) (0.22.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from wandb->nemo_toolkit[all]) (3.1.41)
# Requirement already satisfied: setproctitle in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from wandb->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from wandb->nemo_toolkit[all]) (5.9.8)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from wandb->nemo_toolkit[all]) (1.40.3)
# Requirement already satisfied: fasteners in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from zarr->nemo_toolkit[all]) (0.19)
# Requirement already satisfied: asciitree in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from zarr->nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from zarr->nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.39->boto3->nemo_toolkit[all]) (2.0.7)
# Requirement already satisfied: pycparser in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: itsdangerous>=2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from Flask>=0.8->flask-restful->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[all]) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[all]) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[all]) (6.0.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[all]) (4.0.11)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (4.9.0)
# Requirement already satisfied: stack-data in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (3.0.43)
# Requirement already satisfied: matplotlib-inline in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from jinja2->torch->nemo_toolkit[all]) (2.1.4)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pooch>=1.0->librosa>=0.10.0->nemo_toolkit[all]) (4.1.0)
# Requirement already satisfied: typer[all]>=0.2.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[all]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[all]) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[all]) (3.3.2)
# Requirement already satisfied: mpmath>=0.19 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from sympy->torch->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from beautifulsoup4->gdown->nemo_toolkit[all]) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (13.7.0)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.5.4)
# Requirement already satisfied: asttokens>=2.1.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: pure-eval in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/michal/.pyenv/versions/3.10.11/envs/marvin/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.EncDecHybridRNNTCTCBPEModel.from_pretrained(model_name="nvidia/stt_pl_fastconformer_hybrid_large_pc")
# Out:
# [NeMo I 2024-02-11 19:21:11 mixins:170] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2024-02-11 19:21:12 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath:
#     - /datasets/pl_asr_dataset/mcv-train.json
#     - /datasets/pl_asr_dataset/mls-train.json
#     - /datasets/pl_asr_dataset/voxpopuli-train.json
#     sample_rate: 16000
#     batch_size: 64
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2024-02-11 19:21:12 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath:
#     - /datasets/pl_asr_dataset/dev.json
#     - /datasets/pl_asr_dataset/mcv-dev.json
#     - /datasets/pl_asr_dataset/mls-dev.json
#     - /datasets/pl_asr_dataset/voxpopuli-dev.json
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     max_duration: 20
#
# [NeMo W 2024-02-11 19:21:12 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2024-02-11 19:21:12 features:289] PADDING: 0
# [NeMo I 2024-02-11 19:21:13 rnnt_models:211] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo I 2024-02-11 19:21:14 save_restore_connector:249] Model EncDecHybridRNNTCTCBPEModel was successfully restored from /home/michal/.cache/huggingface/hub/models--nvidia--stt_pl_fastconformer_hybrid_large_pc/snapshots/da899ef006ca22513b41e4a23fa936f7eed319fb/stt_pl_fastconformer_hybrid_large_pc.nemo.

# %%
files = ['test.wav']
for fname, transcription in zip(files, asr_model.transcribe(paths2audio_files=files)):
  print(f"Audio in {fname} was recognized as: {transcription}")
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]
# Audio in test.wav was recognized as: ['Okręt posiada dziewięć silników, napędzających trzy wały napędowe. Do każdego wału podłączony jest zerowinników, trzytłoków i osiem cylindrów.']
